# %%
import pandas as pd
import numpy as np

# %%
radiomics_df = pd.read_csv("radiomics_df_final.csv")

radiomics_df.isna().sum()
# Out:
# Unnamed: 0                                                          0
# pv_Liver_original_shape_Elongation                                  0
# pv_Liver_original_shape_Flatness                                    0
# pv_Liver_original_shape_LeastAxisLength                             0
# pv_Liver_original_shape_MajorAxisLength                             0
#                                                                    ..
# delayed_Mass_original_gldm_SmallDependenceHighGrayLevelEmphasis    74
# delayed_Mass_original_gldm_SmallDependenceLowGrayLevelEmphasis     74
# TCIA_ID                                                             0
# responder                                                           0
# final_mRecist                                                       5
# Length: 860, dtype: int64
